# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
salarios = pd.read_csv('Position_Salaries.csv')

# %%
salarios.head()
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
X = salarios.iloc[:, 1:-1].values
y = salarios.iloc[:, -1].values

# %% [markdown]
# ## Regressão linear simples

# %%
from sklearn.linear_model import LinearRegression
lr_1 = LinearRegression()
lr_1.fit(X, y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
pf = PolynomialFeatures(degree=2)
X_poly = pf.fit_transform(X)
lr_2 = LinearRegression()
lr_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualizando os resultados

# %% [markdown]
# ## Regressão linear

# %%
plt.scatter(X, y, color="red")
plt.plot(X, lr_1.predict(X), color="blue")
plt.title('Nível versus Salários (RL)')
plt.xlabel('Nível')
plt.ylabel('Salário')
# Out:
# Text(0, 0.5, 'Salário')

# %%
from sklearn.metrics import mean_squared_error
y_pred = lr_1.predict(X)
rmse = np.sqrt(mean_squared_error(y, y_pred))
print('RMSE {}'.format(rmse))
# Out:
# RMSE 163388.73519272613

# %% [markdown]
# ## Regressão polinomial

# %%
plt.scatter(X, y, color="red")
plt.plot(X, lr_2.predict(X_poly), color="blue")
plt.title('Nível versus Salários (RL)')
plt.xlabel('Nível')
plt.ylabel('Salário')
# Out:
# Text(0, 0.5, 'Salário')

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

y_pred = lr_2.predict(X_poly)
mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mean_squared_error(y, y_pred))

print('Comparação enntre metricas de erros:')
print('MAE {}'.format(mae))
print('MSE {}'.format(mse))
print('RMSE {}'.format(rmse))
# Out:
# Comparação enntre metricas de erros:
# MAE 70218.1818181819
# MSE 6758833333.333336
# RMSE 82212.12400451247

# %% [markdown]
# A transformação polinomial foi benefica, ela diminuiu pela metade os erros.
# Obs: RMSE é uma das medidas mais utilizadas se tratando de erros.
