# %%
# !pip install python-youtube
# !pip install dataclasses-json
# Out:
# Requirement already satisfied: python-youtube in /usr/local/lib/python3.6/dist-packages (0.6.0)
# Requirement already satisfied: responses in /usr/local/lib/python3.6/dist-packages (from python-youtube) (0.10.14)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.6/dist-packages (from python-youtube) (1.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from python-youtube) (2.23.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from python-youtube) (2018.9)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.6/dist-packages (from python-youtube) (0.4.2)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from python-youtube) (0.16.0)
# Requirement already satisfied: isodate in /usr/local/lib/python3.6/dist-packages (from python-youtube) (0.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from responses->python-youtube) (1.12.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib->python-youtube) (3.1.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->python-youtube) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->python-youtube) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->python-youtube) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->python-youtube) (2020.4.5.1)
# Requirement already satisfied: dataclasses; python_version == "3.6" in /usr/local/lib/python3.6/dist-packages (from dataclasses-json->python-youtube) (0.7)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /usr/local/lib/python3.6/dist-packages (from dataclasses-json->python-youtube) (3.6.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /usr/local/lib/python3.6/dist-packages (from dataclasses-json->python-youtube) (1.5.1)
# Requirement already satisfied: stringcase<2.0.0,==1.2.0 in /usr/local/lib/python3.6/dist-packages (from dataclasses-json->python-youtube) (1.2.0)
# Requirement already satisfied: typing-inspect>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from dataclasses-json->python-youtube) (0.6.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from typing-inspect>=0.4.0->dataclasses-json->python-youtube) (0.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.6/dist-packages (from typing-inspect>=0.4.0->dataclasses-json->python-youtube) (3.7.4.2)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.6/dist-packages (0.4.2)
# Requirement already satisfied: typing-inspect>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from dataclasses-json) (0.6.0)
# Requirement already satisfied: dataclasses; python_version == "3.6" in /usr/local/lib/python3.6/dist-packages (from dataclasses-json) (0.7)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /usr/local/lib/python3.6/dist-packages (from dataclasses-json) (1.5.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /usr/local/lib/python3.6/dist-packages (from dataclasses-json) (3.6.0)
# Requirement already satisfied: stringcase<2.0.0,==1.2.0 in /usr/local/lib/python3.6/dist-packages (from dataclasses-json) (1.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from typing-inspect>=0.4.0->dataclasses-json) (0.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.6/dist-packages (from typing-inspect>=0.4.0->dataclasses-json) (3.7.4.2)

# %% [markdown]
# Importa as libs

# %%
from pyyoutube import Api

import skimage
from skimage import io, exposure
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# API Key

# %%
api_key = 'AIzaSyD4EwG9SXYMo7tbI0JW3isJ7Od5j7N1-7A'
api = Api(api_key=api_key)

# %% [markdown]
# Coleta dos dados

# %%
for url in ['V7oUDL7E1g4']:
  
  ## Acessando o link da thumbnail pela API do YouTube
  video_by_id = api.get_video_by_id(video_id=url)
  thumbnail_url = video_by_id.items[0].to_dict()['snippet']['thumbnails']['medium']['url']
  from pprint import pprint
  pprint(video_by_id.items[0].to_dict()['snippet']['localized'])
  ## Lendo a imagem
  img = skimage.img_as_float(io.imread(thumbnail_url))
  plt.imshow(img)
# Out:
# {'description': 'Faz anos que você ouve falar que "programar é fácil" ou '
#                 '"qualquer um consegue programar". Eu mesmo já disse coisas '
#                 'parecidas.\n'
#                 '\n'
#                 'Hoje eu quero explicar porque na última década a programação '
#                 'alcançou esse status bizarro de "salvador da pátria" e porque '
#                 'os mercados estão num momento desproporcional de abundância, '
#                 'e o que isso pode significar pra sua carreira.\n'
#                 '\n'
#                 '\n'
#                 'Warning: quem achou outros vídeos um "tapa na cara" ou '
#                 '"pedrada", entre neste com cuidado porque pode ser pior. '
#                 'Frágeis de ego: eu avisei.\n'
#                 '\n'
#                 '\n'
#                 '\n'
#                 'Me siga nas redes sociais:\n'
#                 '\n'
#                 '* Twitter (https://twitter.com/akitaonrails)\n'
#                 '* Instagram (https://instagram.com/akitaonrails)\n'
#                 '* Facebook (https://facebook.com/akitaonrails)\n'
#                 '* Podcasts (https://anchor.fm/akitando)\n'
#                 '\n'
#                 '\n'
#                 'Podcast: https://anchor.fm/dashboard/episode/ebvtui\n'
#                 'Transcript: '
#                 'https://www.akitaonrails.com/2020/02/19/akitando-72-rant-programacao-nao-e-facil',
#  'title': 'RANT: Programação NÃO É Fácil'}
